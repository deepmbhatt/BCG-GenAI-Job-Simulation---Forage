# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/revenue.csv')

# %%
df['Revenue Growth (%)'] = df.groupby(['Company'])['Total Revenue'].pct_change() * 100
df['Net Income Growth (%)'] = df.groupby(['Company'])['Net Income'].pct_change() * 100
df['Assests Growth (%)'] = df.groupby(['Company'])['Total Assets'].pct_change() * 100
df['Total Liabilities Growth (%)'] = df.groupby(['Company'])['Total Liabilities'].pct_change() * 100
df['Cash Flow Growth (%)'] = df.groupby(['Company'])['Cash Flow'].pct_change() * 100

# %%
df
# Out:
#    Index    Company  Year  Total Revenue  Net Income  Total Assets  \
# 0      1      Apple  2023           8200       96995        352583
# 1      2      Apple  2022           7500       99808        352755
# 2      3      Apple  2021           6700       94680        351002
# 3      4  Microsoft  2024         245122       88136        512163
# 4      5  Microsoft  2023         211915       72361        411976
# 5      6  Microsoft  2022         198270       72738        364840
# 6      7      Tesla  2023          96773       14974        106618
# 7      8      Tesla  2022          81462       12556         82338
# 8      9      Tesla  2021          53823        5519         62131
#
#    Total Liabilities  Cash Flow  Unnamed: 8  Unnamed: 9  Revenue Growth (%)  \
# 0             290437      24977         NaN         NaN                 NaN
# 1             302083      35929         NaN         NaN           -8.536585
# ...

# %%
df.describe()
# Out:
#           Index         Year  Total Revenue    Net Income   Total Assets  \
# count  9.000000     9.000000       9.000000      9.000000       9.000000
# mean   5.000000  2022.333333  101085.000000  61974.111111  288489.555556
# std    2.738613     1.000000   94476.535636  39487.456697  162044.687899
# min    1.000000  2021.000000    6700.000000   5519.000000   62131.000000
# 25%    3.000000  2022.000000    8200.000000  14974.000000  106618.000000
# 50%    5.000000  2022.000000   81462.000000  72738.000000  352583.000000
# 75%    7.000000  2023.000000  198270.000000  94680.000000  364840.000000
# max    9.000000  2024.000000  245122.000000  99808.000000  512163.000000
#
#        Total Liabilities     Cash Flow  Unnamed: 8  Unnamed: 9  \
# count           9.000000      9.000000         0.0         0.0
# mean       182018.444444  18497.555556         NaN         NaN
# std        114823.109028  13192.784904         NaN         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Index                         9 non-null      int64
#  1   Company                       9 non-null      object
#  2   Year                          9 non-null      int64
#  3   Total Revenue                 9 non-null      int64
#  4   Net Income                    9 non-null      int64
#  5   Total Assets                  9 non-null      int64
#  6   Total Liabilities             9 non-null      int64
#  7   Cash Flow                     9 non-null      int64
#  8   Unnamed: 8                    0 non-null      float64
#  9   Unnamed: 9                    0 non-null      float64
#  10  Revenue Growth (%)            6 non-null      float64
#  11  Net Income Growth (%)         6 non-null      float64
# ...

# %%
df.fillna(0, inplace=True)

# %%
df.to_csv("./data/final_report.csv", index=False)

# %%
summary = df.groupby('Company').agg({'Revenue Growth (%)': 'mean',
    'Net Income Growth (%)': 'mean',
    'Assests Growth (%)' : 'mean',
    'Total Liabilities Growth (%)' : 'mean',
    'Cash Flow Growth (%)' :'mean'}).reset_index()

# %% [markdown]
# # The Year-By-Year Average Growth Rates for: Apple, Microsoft and Tesla

# %%
summary
# Out:
#      Company  Revenue Growth (%)  Net Income Growth (%)  Assests Growth (%)  \
# 0      Apple           -6.401084              -0.745905           -0.149388
# 1  Microsoft           -6.662011              -5.792492          -10.334330
# 2      Tesla          -16.583422             -24.064303          -15.771471
#
#    Total Liabilities Growth (%)  Cash Flow Growth (%)
# 0                     -0.227092             18.197250
# 1                     -6.396540            -12.278619
# 2                    -10.480864              1.889005

# %%
summary.to_csv("./data/summary.csv", index=False)
